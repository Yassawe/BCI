# %%
import numpy as np
import scipy.linalg as la
import mne.filter as bandpass_filter
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import geomstats as gs
import geomstats.geometry.spd_matrices as spd
from geomstats.learning.frechet_mean import FrechetMean
from scipy.io import loadmat

# %%
class RCSP:
    def __init__(self, channels):
        self.channels = channels
        self.V=None
      
    def bandpass(self, X, fs, fl, fh):
        X = np.swapaxes(X, 1, 2)
        X = bandpass_filter.filter_data(X, fs, fl, fh, verbose=False)
        X = np.swapaxes(X, 1, 2)
        return X
        
    def calculateCovariances(self, X):
        covlist = np.empty((X.shape[0], X.shape[2], X.shape[2]))
        for i in range(len(X)):
            epoch = X[i]
            covlist[i] = np.dot(epoch.T, epoch)
        return covlist
    
    def estimateMeans(self, classSpecificCOV, metric):
        if metric=="AIRM":
            estimator = FrechetMean(spd.SPDMetricAffine(n=self.channels), max_iter=64)
        elif metric=="LEM":
            estimator = FrechetMean(spd.SPDMetricLogEuclidean(n=self.channels), max_iter=64)
        elif metric=="BW":
            estimator = FrechetMean(spd.SPDMetricBuresWasserstein(n=self.channels), max_iter=64) #doesn't work yet
        else:
            raise Exception("Not implemented metric")
            
        means = []
        
        for COV in classSpecificCOV:
            estimator.fit(COV)
            mean = estimator.estimate_
            means.append(mean)
        return means
    
    
    def separate_classes(self, X, Y):
        classSpecificCOV = []
        for i in range(2): 
            ind = np.where(Y==i)[0]
            classCOV = X[ind]
            classSpecificCOV.append(classCOV)
        return classSpecificCOV
    
    def CSP(self, X, Y, metric, n):
        classSpecificCOV = self.separate_classes(X, Y)
        if metric == "classic":
            class0_avg = sum(classSpecificCOV[0])/len(classSpecificCOV[0])
            class1_avg = sum(classSpecificCOV[1])/len(classSpecificCOV[1])
        else:
            class0_avg, class1_avg = self.estimateMeans(classSpecificCOV, metric)

        _,V = la.eigh(class0_avg, class0_avg+class1_avg)
        V = np.concatenate((V[:, :n], V[:, -n:]), axis=1)
        
        return V
    
    def applyCSP(self, dk, V):
        a = np.dot(np.dot(V.T, dk), V) 
        f = np.log(np.diagonal(a)/np.trace(a)) 
        return f
    
    def get_mi_features(self, data, metric="classic", mode="train", fs=1000, fl=8, fh=30, n=3):

        channels = [7, 8, 9, 10, 12, 13, 14, 17, 18, 19, 20, 32, 33, 34, 35, 36, 37, 38, 39, 40] #standard 10/20 cap mapping, electrodes responsible for MI

        X = data['smt'][0][0][1000:3500, :, channels]
        Y = data['y_dec'][0][0][0]

        X = np.swapaxes(X, 0, 1)
        Y = Y-1

        filteredX = self.bandpass(X, fs, fl, fh)
        print(filteredX.shape)
        covX = self.calculateCovariances(filteredX)
        
        if mode=="train":
            V = self.CSP(covX, Y, metric, n)
            self.V = V
        else:
            if self.V is None:
                raise Exception("train CSP first please")
            V=self.V
        
        features = np.empty((len(X), 2*n))
  
        for i in range(len(X)):
            epoch = covX[i]
            features[i] = self.applyCSP(epoch, V) 
            
        return features, Y

# %%
csp = RCSP(20)

# %%
metrics = ["classic", "AIRM", "LEM"]
ns = [2,3,4,5]

for n in ns:
    print("N is " + str(n) + "\n")
    for metric in metrics:
        
        print("Metric is " + metric)
        av = []
        for i in range(1,21):        
            filename = 'datasets/54subjects/sess01/subj{}_EEG_MI.mat'.format(i)
            data = loadmat(filename)
            train = data['EEG_MI_train']
            test = data['EEG_MI_test']
    
            trainX, trainY = csp.get_mi_features(train, metric=metric, mode="train", n=n)
            testX, testY = csp.get_mi_features(test, metric=metric, mode="test", n=n)
            clf = LDA()
            clf.fit(trainX, trainY)
            res = clf.score(testX, testY)
            av.append(res)
            print("Subject " + str(i) + ", accuracy = " + str(res))
        print("Average is " + str(sum(av)/len(av)) + "\n")
# Out:
# N is 2
#
# Metric is classic
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.6
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.78
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.57
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.72
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.56
# Average is 0.664
#
# Metric is AIRM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.71
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.42
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.69
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.85
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.65
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.79
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.56
# Average is 0.6704999999999999
#
# Metric is LEM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.7
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.96
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.96
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.75
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.59
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.87
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.62
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.43
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.57
# Average is 0.6719999999999999
#
# N is 3
#
# Metric is classic
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.63
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.57
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.89
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.79
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.61
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.61
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.72
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.54
# Average is 0.667
#
# Metric is AIRM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.73
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.94
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.96
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.42
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.92
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.74
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.63
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.79
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.64
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.53
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.82
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.54
# Average is 0.6744999999999999
#
# Metric is LEM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.71
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.94
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.48
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.73
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.48
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.59
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.8
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.62
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.59
# Average is 0.6765
#
# N is 4
#
# Metric is classic
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.63
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.94
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.86
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.76
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.53
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.78
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.65
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.71
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.9
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.56
# Average is 0.6639999999999999
#
# Metric is AIRM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.71
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.46
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.86
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.67
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.6
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.8
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.66
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.46
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.44
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.6
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.85
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.9
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.88
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.57
# Average is 0.6685000000000001
#
# Metric is LEM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.71
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.95
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.86
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.75
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.6
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.63
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.46
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.56
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.89
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.82
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.6
# Average is 0.6765000000000001
#
# N is 5
#
# Metric is classic
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.59
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.94
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.77
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.55
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.61
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.79
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.63
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.45
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.48
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.5
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.65
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.85
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.55
# Average is 0.649
#
# Metric is AIRM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.67
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.94
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.46
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.7
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.47
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.57
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.8
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.64
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.47
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.44
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.57
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.83
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.88
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.86
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.55
# Average is 0.659
#
# Metric is LEM
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 1, accuracy = 0.74
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 2, accuracy = 0.91
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 3, accuracy = 0.93
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 4, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 5, accuracy = 0.84
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 6, accuracy = 0.72
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 7, accuracy = 0.47
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 8, accuracy = 0.54
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 9, accuracy = 0.76
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 10, accuracy = 0.66
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 11, accuracy = 0.52
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 12, accuracy = 0.43
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 13, accuracy = 0.51
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 14, accuracy = 0.47
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 15, accuracy = 0.58
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 16, accuracy = 0.49
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 17, accuracy = 0.81
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 18, accuracy = 0.88
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 19, accuracy = 0.82
# (100, 2500, 20)
# (100, 2500, 20)
# Subject 20, accuracy = 0.58
# Average is 0.659

# %%
csp = RCSP(20)

# %%
metrics = ["classic", "AIRM", "LEM"]
ns = [2,3,4,5]

for n in ns:
    print("N is " + str(n) + "\n")
    for metric in metrics:
        
        print("Metric is " + metric)
        av = []
        for i in range(1,21):        
            filename = 'datasets/54subjects/sess01/subj{}_EEG_MI.mat'.format(i)
            data = loadmat(filename)
            train = data['EEG_MI_train']
            test = data['EEG_MI_test']
    
            trainX, trainY = csp.get_mi_features(train, metric=metric, mode="train", n=n)
            testX, testY = csp.get_mi_features(test, metric=metric, mode="test", n=n)
            clf = LDA()
            clf.fit(trainX, trainY)
            res = clf.score(testX, testY)
            av.append(res)
            print("Subject " + str(i) + ", accuracy = " + str(res))
        print("Average is " + str(sum(av)/len(av)) + "\n")
# Out:
# N is 2
#
# Metric is classic
# Subject 1, accuracy = 0.6
# Subject 2, accuracy = 0.95
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.55
# Subject 5, accuracy = 0.92
# Subject 6, accuracy = 0.78
# Subject 7, accuracy = 0.5
# Subject 8, accuracy = 0.55
# Subject 9, accuracy = 0.83
# Subject 10, accuracy = 0.56
# Subject 11, accuracy = 0.45
# Subject 12, accuracy = 0.49
# Subject 13, accuracy = 0.56
# Subject 14, accuracy = 0.57
# Subject 15, accuracy = 0.51
# Subject 16, accuracy = 0.5
# Subject 17, accuracy = 0.72
# Subject 18, accuracy = 0.92
# Subject 19, accuracy = 0.81
# Subject 20, accuracy = 0.56
# Average is 0.664
#
# Metric is AIRM
# Subject 1, accuracy = 0.71
# Subject 2, accuracy = 0.95
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.42
# Subject 5, accuracy = 0.92
# Subject 6, accuracy = 0.69
# Subject 7, accuracy = 0.56
# Subject 8, accuracy = 0.56
# Subject 9, accuracy = 0.85
# Subject 10, accuracy = 0.65
# Subject 11, accuracy = 0.52
# Subject 12, accuracy = 0.45
# Subject 13, accuracy = 0.54
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.52
# Subject 16, accuracy = 0.52
# Subject 17, accuracy = 0.83
# Subject 18, accuracy = 0.91
# Subject 19, accuracy = 0.79
# Subject 20, accuracy = 0.56
# Average is 0.6704999999999999
#
# Metric is LEM
# Subject 1, accuracy = 0.7
# Subject 2, accuracy = 0.96
# Subject 3, accuracy = 0.96
# Subject 4, accuracy = 0.45
# Subject 5, accuracy = 0.92
# Subject 6, accuracy = 0.75
# Subject 7, accuracy = 0.55
# Subject 8, accuracy = 0.59
# Subject 9, accuracy = 0.87
# Subject 10, accuracy = 0.62
# Subject 11, accuracy = 0.43
# Subject 12, accuracy = 0.45
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.5
# Subject 16, accuracy = 0.51
# Subject 17, accuracy = 0.84
# Subject 18, accuracy = 0.91
# Subject 19, accuracy = 0.84
# Subject 20, accuracy = 0.57
# Average is 0.6719999999999999
#
# N is 3
#
# Metric is classic
# Subject 1, accuracy = 0.63
# Subject 2, accuracy = 0.93
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.57
# Subject 5, accuracy = 0.89
# Subject 6, accuracy = 0.79
# Subject 7, accuracy = 0.51
# Subject 8, accuracy = 0.61
# Subject 9, accuracy = 0.83
# Subject 10, accuracy = 0.61
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.49
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.49
# Subject 16, accuracy = 0.52
# Subject 17, accuracy = 0.72
# Subject 18, accuracy = 0.92
# Subject 19, accuracy = 0.83
# Subject 20, accuracy = 0.54
# Average is 0.667
#
# Metric is AIRM
# Subject 1, accuracy = 0.73
# Subject 2, accuracy = 0.94
# Subject 3, accuracy = 0.96
# Subject 4, accuracy = 0.42
# Subject 5, accuracy = 0.92
# Subject 6, accuracy = 0.74
# Subject 7, accuracy = 0.51
# Subject 8, accuracy = 0.63
# Subject 9, accuracy = 0.79
# Subject 10, accuracy = 0.64
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.5
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.54
# Subject 16, accuracy = 0.53
# Subject 17, accuracy = 0.82
# Subject 18, accuracy = 0.93
# Subject 19, accuracy = 0.84
# Subject 20, accuracy = 0.54
# Average is 0.6744999999999999
#
# Metric is LEM
# Subject 1, accuracy = 0.71
# Subject 2, accuracy = 0.94
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.48
# Subject 5, accuracy = 0.91
# Subject 6, accuracy = 0.73
# Subject 7, accuracy = 0.48
# Subject 8, accuracy = 0.59
# Subject 9, accuracy = 0.8
# Subject 10, accuracy = 0.62
# Subject 11, accuracy = 0.52
# Subject 12, accuracy = 0.5
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.54
# Subject 15, accuracy = 0.55
# Subject 16, accuracy = 0.55
# Subject 17, accuracy = 0.81
# Subject 18, accuracy = 0.91
# Subject 19, accuracy = 0.84
# Subject 20, accuracy = 0.59
# Average is 0.6765
#
# N is 4
#
# Metric is classic
# Subject 1, accuracy = 0.63
# Subject 2, accuracy = 0.94
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.52
# Subject 5, accuracy = 0.86
# Subject 6, accuracy = 0.76
# Subject 7, accuracy = 0.53
# Subject 8, accuracy = 0.55
# Subject 9, accuracy = 0.78
# Subject 10, accuracy = 0.65
# Subject 11, accuracy = 0.54
# Subject 12, accuracy = 0.49
# Subject 13, accuracy = 0.5
# Subject 14, accuracy = 0.52
# Subject 15, accuracy = 0.52
# Subject 16, accuracy = 0.54
# Subject 17, accuracy = 0.71
# Subject 18, accuracy = 0.9
# Subject 19, accuracy = 0.83
# Subject 20, accuracy = 0.56
# Average is 0.6639999999999999
#
# Metric is AIRM
# Subject 1, accuracy = 0.71
# Subject 2, accuracy = 0.93
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.46
# Subject 5, accuracy = 0.86
# Subject 6, accuracy = 0.67
# Subject 7, accuracy = 0.45
# Subject 8, accuracy = 0.6
# Subject 9, accuracy = 0.8
# Subject 10, accuracy = 0.66
# Subject 11, accuracy = 0.52
# Subject 12, accuracy = 0.46
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.44
# Subject 15, accuracy = 0.6
# Subject 16, accuracy = 0.55
# Subject 17, accuracy = 0.85
# Subject 18, accuracy = 0.9
# Subject 19, accuracy = 0.88
# Subject 20, accuracy = 0.57
# Average is 0.6685000000000001
#
# Metric is LEM
# Subject 1, accuracy = 0.71
# Subject 2, accuracy = 0.93
# Subject 3, accuracy = 0.95
# Subject 4, accuracy = 0.5
# Subject 5, accuracy = 0.86
# Subject 6, accuracy = 0.75
# Subject 7, accuracy = 0.51
# Subject 8, accuracy = 0.6
# Subject 9, accuracy = 0.81
# Subject 10, accuracy = 0.63
# Subject 11, accuracy = 0.56
# Subject 12, accuracy = 0.49
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.46
# Subject 15, accuracy = 0.55
# Subject 16, accuracy = 0.56
# Subject 17, accuracy = 0.84
# Subject 18, accuracy = 0.89
# Subject 19, accuracy = 0.82
# Subject 20, accuracy = 0.6
# Average is 0.6765000000000001
#
# N is 5
#
# Metric is classic
# Subject 1, accuracy = 0.59
# Subject 2, accuracy = 0.93
# Subject 3, accuracy = 0.94
# Subject 4, accuracy = 0.45
# Subject 5, accuracy = 0.81
# Subject 6, accuracy = 0.77
# Subject 7, accuracy = 0.55
# Subject 8, accuracy = 0.61
# Subject 9, accuracy = 0.79
# Subject 10, accuracy = 0.63
# Subject 11, accuracy = 0.45
# Subject 12, accuracy = 0.5
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.48
# Subject 15, accuracy = 0.5
# Subject 16, accuracy = 0.51
# Subject 17, accuracy = 0.65
# Subject 18, accuracy = 0.91
# Subject 19, accuracy = 0.85
# Subject 20, accuracy = 0.55
# Average is 0.649
#
# Metric is AIRM
# Subject 1, accuracy = 0.67
# Subject 2, accuracy = 0.94
# Subject 3, accuracy = 0.93
# Subject 4, accuracy = 0.46
# Subject 5, accuracy = 0.81
# Subject 6, accuracy = 0.7
# Subject 7, accuracy = 0.47
# Subject 8, accuracy = 0.57
# Subject 9, accuracy = 0.8
# Subject 10, accuracy = 0.64
# Subject 11, accuracy = 0.54
# Subject 12, accuracy = 0.47
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.44
# Subject 15, accuracy = 0.57
# Subject 16, accuracy = 0.54
# Subject 17, accuracy = 0.83
# Subject 18, accuracy = 0.88
# Subject 19, accuracy = 0.86
# Subject 20, accuracy = 0.55
# Average is 0.659
#
# Metric is LEM
# Subject 1, accuracy = 0.74
# Subject 2, accuracy = 0.91
# Subject 3, accuracy = 0.93
# Subject 4, accuracy = 0.52
# Subject 5, accuracy = 0.84
# Subject 6, accuracy = 0.72
# Subject 7, accuracy = 0.47
# Subject 8, accuracy = 0.54
# Subject 9, accuracy = 0.76
# Subject 10, accuracy = 0.66
# Subject 11, accuracy = 0.52
# Subject 12, accuracy = 0.43
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.47
# Subject 15, accuracy = 0.58
# Subject 16, accuracy = 0.49
# Subject 17, accuracy = 0.81
# Subject 18, accuracy = 0.88
# Subject 19, accuracy = 0.82
# Subject 20, accuracy = 0.58
# Average is 0.659

# %%
metrics = ["classic", "AIRM", "LEM"]
ns = [2,3,4,5]

for n in ns:
    print("N is " + str(n) + "\n")
    for metric in metrics:
        
        print("Metric is " + metric)
        av = []
        for i in range(1,21):        
            filename = 'datasets/54subjects/sess01/subj{}_EEG_MI.mat'.format(i)
            data = loadmat(filename)
            train = data['EEG_MI_train']
            test = data['EEG_MI_test']
    
            trainX, trainY = csp.get_mi_features(train, metric=metric, mode="train", n=n)
            testX, testY = csp.get_mi_features(test, metric=metric, mode="test", n=n)
            clf = LDA()
            clf.fit(trainX, trainY)
            res = clf.score(testX, testY)
            av.append(res)
            print("Subject " + str(i) + ", accuracy = " + str(res))
        print("Average is " + str(sum(av)/len(av)) + "\n")
# Out:
# N is 2
#
# Metric is classic
# Subject 1, accuracy = 0.8
# Subject 2, accuracy = 0.83
# Subject 4, accuracy = 0.58
# Subject 5, accuracy = 0.8
# Subject 6, accuracy = 0.81
# Subject 7, accuracy = 0.61
# Subject 8, accuracy = 0.58
# Subject 9, accuracy = 0.7
# Subject 10, accuracy = 0.59
# Subject 11, accuracy = 0.48
# Subject 12, accuracy = 0.59
# Subject 13, accuracy = 0.5
# Subject 14, accuracy = 0.56
# Subject 15, accuracy = 0.52
# Subject 16, accuracy = 0.68
# Subject 17, accuracy = 0.7
# Subject 18, accuracy = 0.85
# Subject 19, accuracy = 0.79
# Subject 20, accuracy = 0.61
# Average is 0.6621052631578946
#
# Metric is AIRM
# Subject 1, accuracy = 0.79
# Subject 2, accuracy = 0.81
# Subject 4, accuracy = 0.56
# Subject 5, accuracy = 0.81
# Subject 6, accuracy = 0.87
# Subject 7, accuracy = 0.65
# Subject 8, accuracy = 0.63
# Subject 9, accuracy = 0.71
# Subject 10, accuracy = 0.66
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.59
# Subject 13, accuracy = 0.52
# Subject 14, accuracy = 0.45
# Subject 15, accuracy = 0.54
# Subject 16, accuracy = 0.74
# Subject 17, accuracy = 0.76
# Subject 18, accuracy = 0.87
# Subject 19, accuracy = 0.78
# Subject 20, accuracy = 0.67
# Average is 0.6789473684210524
#
# Metric is LEM
# Subject 1, accuracy = 0.8
# Subject 2, accuracy = 0.83
# Subject 4, accuracy = 0.55
# Subject 5, accuracy = 0.82
# Subject 6, accuracy = 0.85
# Subject 7, accuracy = 0.58
# Subject 8, accuracy = 0.64
# Subject 9, accuracy = 0.7
# Subject 10, accuracy = 0.66
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.6
# Subject 13, accuracy = 0.47
# Subject 14, accuracy = 0.46
# Subject 15, accuracy = 0.54
# Subject 16, accuracy = 0.76
# Subject 17, accuracy = 0.75
# Subject 18, accuracy = 0.87
# Subject 19, accuracy = 0.79
# Subject 20, accuracy = 0.66
# Average is 0.674736842105263
#
# N is 3
#
# Metric is classic
# Subject 1, accuracy = 0.8
# Subject 2, accuracy = 0.9
# Subject 4, accuracy = 0.58
# Subject 5, accuracy = 0.85
# Subject 6, accuracy = 0.77
# Subject 7, accuracy = 0.68
# Subject 8, accuracy = 0.51
# Subject 9, accuracy = 0.69
# Subject 10, accuracy = 0.58
# Subject 11, accuracy = 0.5
# Subject 12, accuracy = 0.56
# Subject 13, accuracy = 0.55
# Subject 14, accuracy = 0.46
# Subject 15, accuracy = 0.58
# Subject 16, accuracy = 0.59
# Subject 17, accuracy = 0.67
# Subject 18, accuracy = 0.83
# Subject 19, accuracy = 0.78
# Subject 20, accuracy = 0.6
# Average is 0.6568421052631578
#
# Metric is AIRM
# Subject 1, accuracy = 0.71
# Subject 2, accuracy = 0.89
# Subject 4, accuracy = 0.6
# Subject 5, accuracy = 0.78
# Subject 6, accuracy = 0.9
# Subject 7, accuracy = 0.66
# Subject 8, accuracy = 0.55
# Subject 9, accuracy = 0.71
# Subject 10, accuracy = 0.67
# Subject 11, accuracy = 0.47
# Subject 12, accuracy = 0.56
# Subject 13, accuracy = 0.51
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.6
# Subject 16, accuracy = 0.75
# Subject 17, accuracy = 0.72
# Subject 18, accuracy = 0.87
# Subject 19, accuracy = 0.81
# Subject 20, accuracy = 0.72
# Average is 0.6836842105263158
#
# Metric is LEM
# Subject 1, accuracy = 0.78
# Subject 2, accuracy = 0.86
# Subject 4, accuracy = 0.62
# Subject 5, accuracy = 0.81
# Subject 6, accuracy = 0.88
# Subject 7, accuracy = 0.62
# Subject 8, accuracy = 0.53
# Subject 9, accuracy = 0.71
# Subject 10, accuracy = 0.68
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.59
# Subject 13, accuracy = 0.48
# Subject 14, accuracy = 0.47
# Subject 15, accuracy = 0.58
# Subject 16, accuracy = 0.77
# Subject 17, accuracy = 0.74
# Subject 18, accuracy = 0.88
# Subject 19, accuracy = 0.83
# Subject 20, accuracy = 0.7
# Average is 0.6852631578947369
#
# N is 4
#
# Metric is classic
# Subject 1, accuracy = 0.78
# Subject 2, accuracy = 0.91
# Subject 4, accuracy = 0.55
# Subject 5, accuracy = 0.83
# Subject 6, accuracy = 0.77
# Subject 7, accuracy = 0.69
# Subject 8, accuracy = 0.51
# Subject 9, accuracy = 0.67
# Subject 10, accuracy = 0.63
# Subject 11, accuracy = 0.47
# Subject 12, accuracy = 0.63
# Subject 13, accuracy = 0.59
# Subject 14, accuracy = 0.49
# Subject 15, accuracy = 0.56
# Subject 16, accuracy = 0.67
# Subject 17, accuracy = 0.69
# Subject 18, accuracy = 0.75
# Subject 19, accuracy = 0.8
# Subject 20, accuracy = 0.73
# Average is 0.6694736842105263
#
# Metric is AIRM
# Subject 1, accuracy = 0.75
# Subject 2, accuracy = 0.91
# Subject 4, accuracy = 0.57
# Subject 5, accuracy = 0.81
# Subject 6, accuracy = 0.87
# Subject 7, accuracy = 0.64
# Subject 8, accuracy = 0.54
# Subject 9, accuracy = 0.7
# Subject 10, accuracy = 0.65
# Subject 11, accuracy = 0.46
# Subject 12, accuracy = 0.6
# Subject 13, accuracy = 0.57
# Subject 14, accuracy = 0.5
# Subject 15, accuracy = 0.58
# Subject 16, accuracy = 0.65
# Subject 17, accuracy = 0.76
# Subject 18, accuracy = 0.81
# Subject 19, accuracy = 0.77
# Subject 20, accuracy = 0.79
# Average is 0.6805263157894736
#
# Metric is LEM
# Subject 1, accuracy = 0.76
# Subject 2, accuracy = 0.87
# Subject 4, accuracy = 0.57
# Subject 5, accuracy = 0.82
# Subject 6, accuracy = 0.84
# Subject 7, accuracy = 0.63
# Subject 8, accuracy = 0.53
# Subject 9, accuracy = 0.67
# Subject 10, accuracy = 0.69
# Subject 11, accuracy = 0.49
# Subject 12, accuracy = 0.58
# Subject 13, accuracy = 0.5
# Subject 14, accuracy = 0.49
# Subject 15, accuracy = 0.58
# Subject 16, accuracy = 0.72
# Subject 17, accuracy = 0.76
# Subject 18, accuracy = 0.83
# Subject 19, accuracy = 0.8
# Subject 20, accuracy = 0.8
# Average is 0.6805263157894738
#
# N is 5
#
# Metric is classic
# Subject 1, accuracy = 0.76
# Subject 2, accuracy = 0.86
# Subject 4, accuracy = 0.54
# Subject 5, accuracy = 0.84
# Subject 6, accuracy = 0.77
# Subject 7, accuracy = 0.69
# Subject 8, accuracy = 0.49
# Subject 9, accuracy = 0.68
# Subject 10, accuracy = 0.64
# Subject 11, accuracy = 0.45
# Subject 12, accuracy = 0.6
# Subject 13, accuracy = 0.57
# Subject 14, accuracy = 0.51
# Subject 15, accuracy = 0.6
# Subject 16, accuracy = 0.67
# Subject 17, accuracy = 0.72
# Subject 18, accuracy = 0.75
# Subject 19, accuracy = 0.78
# Subject 20, accuracy = 0.75
# Average is 0.6668421052631579
#
# Metric is AIRM
# Subject 1, accuracy = 0.75
# Subject 2, accuracy = 0.92
# Subject 4, accuracy = 0.53
# Subject 5, accuracy = 0.78
# Subject 6, accuracy = 0.86
# Subject 7, accuracy = 0.68
# Subject 8, accuracy = 0.57
# Subject 9, accuracy = 0.7
# Subject 10, accuracy = 0.64
# Subject 11, accuracy = 0.51
# Subject 12, accuracy = 0.61
# Subject 13, accuracy = 0.49
# Subject 14, accuracy = 0.56
# Subject 15, accuracy = 0.62
# Subject 16, accuracy = 0.65
# Subject 17, accuracy = 0.75
# Subject 18, accuracy = 0.73
# Subject 19, accuracy = 0.77
# Subject 20, accuracy = 0.75
# Average is 0.6773684210526316
#
# Metric is LEM
# Subject 1, accuracy = 0.75
# Subject 2, accuracy = 0.9
# Subject 4, accuracy = 0.54
# Subject 5, accuracy = 0.79
# Subject 6, accuracy = 0.86
# Subject 7, accuracy = 0.65
# Subject 8, accuracy = 0.53
# Subject 9, accuracy = 0.67
# Subject 10, accuracy = 0.62
# Subject 11, accuracy = 0.55
# Subject 12, accuracy = 0.58
# Subject 13, accuracy = 0.48
# Subject 14, accuracy = 0.5
# Subject 15, accuracy = 0.62
# Subject 16, accuracy = 0.76
# Subject 17, accuracy = 0.77
# Subject 18, accuracy = 0.78
# Subject 19, accuracy = 0.77
# Subject 20, accuracy = 0.77
# Average is 0.6784210526315788
